# %% [markdown]
# ### Parkison Disease
# - Its the degeneration of the substantia nigra
# - Its a progressive nervous system disorder that affects movement leading to shaking,stiffness, and difficulty with walking , balance and coordination. The symptoms usually begin gradually and get worse over time

# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Data Collection

# %%
parkinson_data=pd.read_csv("../Data/parkinsons.csv")
parkinson_data.head(n=10)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
# 5  phon_R01_S01_6      120.552       131.162  ...  0.299111  2.187560  0.357775
# 6  phon_R01_S02_1      120.267       137.244  ...  0.257682  1.854785  0.211756
# 7  phon_R01_S02_2      107.332       113.840  ...  0.183721  2.064693  0.163755
# 8  phon_R01_S02_3       95.730       132.068  ...  0.327769  2.322511  0.231571
# 9  phon_R01_S02_4       95.056       120.103  ...  0.325996  2.432792  0.271362
#
# [10 rows x 24 columns]

# %%
parkinson_data.shape
# Out:
# (195, 24)

# %%
# More information about dataset 
parkinson_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
#Cheking for missing values 
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#Statistical measures about data 
parkinson_data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinson_data.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
#Grouping the data based on the target variable 
parkinson_data_mean =parkinson_data.drop(columns=['name'])
parkinson_data_mean.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread2        D2       PPE
# status                                           ...
# 0        181.937771    223.636750    145.207292  ...  0.160292  2.154491  0.123017
# 1        145.180762    188.441463    106.893558  ...  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %% [markdown]
# #### Separating the features from target

# %%
X=parkinson_data.drop(columns=['name','status'],axis=1)
Y=parkinson_data['status']

# %% [markdown]
# #### Train - Test Split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# #### Data Standardization

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train) ## We fit the data with the training data alone so it can have an idea of the data , and then we can  apply it on the test data later on
